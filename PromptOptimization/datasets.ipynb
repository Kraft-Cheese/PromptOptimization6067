# %%
# %pip install datasets
# %run download_datasets.py
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Using the latest cached version of the dataset since piqa couldn't be found on the Hugging Face Hub
# Found the latest cached dataset configuration 'plain_text' at /Users/cassandrehamel/.cache/huggingface/datasets/piqa/plain_text/1.1.0/6c611c1a9bf220943c4174e117d3b660859665baf1d43156230116185312d011 (last modified on Sun Nov  2 19:33:36 2025).
# Saved 100 PIQA examples
# Saved 100 HellaSwag examples
#
# ...
# Saved 100 BoolQ examples
# Saved 100 GSM8K examples
